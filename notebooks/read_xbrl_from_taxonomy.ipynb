# %% [markdown]
# # Read XBRL from Taxonomy
#
# タクソノミ定義の情報を参照して、XBRLから情報抽出を行う。

# %%
import os
from pathlib import Path
import edinet

# サントリーホールディングス株式会社/H31.03.26 12:50
DOC_ID = "S100FGSC"

# Data Folder
DATA_ROOT = Path.cwd().joinpath("data")

# %% [markdown]
# ## Download XBRL

# %%
from edinet.xbrl_file import XBRLDir


# Download and load document
xbrl_path = edinet.api.document.get_xbrl(
    DOC_ID, save_dir=DATA_ROOT.joinpath("raw"),
    expand_level="dir")

xbrl_dir = XBRLDir(xbrl_path)
# Out:
# c:\Users\tie301837\Documents\source\xbrl_read_tutorial\venv\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ## Download Taxonomy
#
# Get taxonomy file

# %%
taxonomies = {
    2013: "https://www.fsa.go.jp/search/20130821/editaxonomy2013New.zip",
    2014: "https://www.fsa.go.jp/search/20140310/1c.zip",
    2015: "https://www.fsa.go.jp/search/20150310/1c.zip",
    2016: "https://www.fsa.go.jp/search/20160314/1c.zip",
    2017: "https://www.fsa.go.jp/search/20170228/1c.zip",
    2018: "https://www.fsa.go.jp/search/20180228/1c_Taxonomy.zip",
    2019: "https://www.fsa.go.jp/search/20190228/1c_Taxonomy.zip"
}

# %% [markdown]
# Confirm fiscal year and target taxonomy

# %%
from datetime import datetime


fiscal_year_end = xbrl_dir.xbrl.find("jpdei_cor:CurrentFiscalYearEndDateDEI").text
fiscal_year_end = datetime.strptime(fiscal_year_end, "%Y-%m-%d")
taxonomy_year = -1

for y in taxonomies:
    boarder_date = datetime(y, 3, 31)
    if fiscal_year_end > boarder_date:
        taxonomy_year = y
    else:
        break

print(taxonomy_year)
# Out:
# 2018

# %% [markdown]
# Download taxonomy

# %%
from zipfile import ZipFile
import requests


external_dir = DATA_ROOT.joinpath("external")
expand_dir = external_dir.joinpath("taxonomy").joinpath(str(taxonomy_year))
taxonomy_file = external_dir.joinpath(f"{taxonomy_year}_taxonomy.zip")

download = False

if not external_dir.exists():
    external_dir.mkdir(parents=True, exist_ok=True)
    download = True

if not expand_dir.exists():
    expand_dir.mkdir(parents=True, exist_ok=True)
    download = True

if download:
    # Download
    external_dir.mkdir(parents=True, exist_ok=True)
    r = requests.get(taxonomies[taxonomy_year], stream=True)
    with taxonomy_file.open(mode="wb") as f:
        for chunk in r.iter_content(1024):
            f.write(chunk)

    # Extract
    with ZipFile(taxonomy_file, "r") as zip:
        for f in zip.namelist():
            # Avoid Japanese path 
            dirs = f.split("/")
            if dirs[2] == "taxonomy":
                _to = expand_dir.joinpath("/".join(dirs[3:]))
                _to.parent.mkdir(parents=True, exist_ok=True)
                with _to.open("wb") as _to_f:
                    _to_f.write(zip.read(f))

    taxonomy_file.unlink()

expand_dir
# Out:
# WindowsPath('c:/Users/tie301837/Documents/source/xbrl_read_tutorial/data/external/taxonomy/2018')

# %%
import os
from bs4 import BeautifulSoup


class TaxonomyReader():


    def __init__(self, root, parent_root, parent_prefix=""):
        self.root = root
        self.parent_root = parent_root
        self.parent_prefix = parent_prefix
        if not self.parent_prefix:
            self.parent_prefix = "http://disclosure.edinet-fsa.go.jp/taxonomy/"
    
    def read(self, path):
        _path = path
        element = ""
        if "#" in _path:
            _path, element = _path.split("#")
            element = "#" + element

        if _path.startswith(self.parent_prefix):
            _path = _path.replace(self.parent_prefix, "")
            _path = os.path.join(self.parent_root, _path)
        else:
            _path = os.path.join(self.root, path)

        xml = None
        with open(_path, encoding="utf-8-sig") as f:
            xml = BeautifulSoup(f, "lxml-xml")
        
        if element:
            xml = xml.select(element)
            if len(xml) > 0:
                xml = xml[0]

        return xml

# %%
taxonomy_reader = TaxonomyReader(xbrl_dir._document_folder, expand_dir)
taxonomy_reader.read("http://disclosure.edinet-fsa.go.jp/taxonomy/jpcrp/2018-02-28/jpcrp_rt_2018-02-28.xsd#rol_CoverPage")
# Out:
# <link:roleType id="rol_CoverPage" roleURI="http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_CoverPage">
# <link:definition>表紙</link:definition>
# <link:usedOn>link:presentationLink</link:usedOn>
# <link:usedOn>link:calculationLink</link:usedOn>
# <link:usedOn>link:definitionLink</link:usedOn>
# <link:usedOn>link:footnoteLink</link:usedOn>
# </link:roleType>

# %% [markdown]
# ## Read Presentation Link

# %%
import dataclasses


@dataclasses.dataclass
class Namespace:
    name: str
    namespace: str

    @classmethod
    def read(cls, schema_tag):
        namespaces = []
        namespace_prefix = "xmlns:"
        for a in schema_tag.attrs:
            if a.startswith(namespace_prefix):
                name = a[len(namespace_prefix):]
                definition = schema_tag[a]
                n = Namespace(name, definition)
                namespaces.append(n)

        return n

# %%
presentation = xbrl_dir.pre
role_ref_tags = presentation.find_all("link:roleRef")
role_refs = {}
for t in role_ref_tags:
    role_refs[t["roleURI"]] = t["xlink:href"]


roles = {}
for p in presentation.find_all("link:presentationLink"):
    role = p["xlink:role"]
    role_href = role_refs[role]
    role_def = taxonomy_reader.read(role_href).find("link:definition").text
    roles[role_def] = role

print(roles)
# Out:
# {'企業内容等の開示に関する内閣府令 第三号様式 有価証券報告書': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo3AnnualSecuritiesReport', '表紙': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_CoverPage', '連結経営指標等': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_BusinessResultsOfGroup', '提出会社の経営指標等': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_BusinessResultsOfReportingCompany', '大株主の状況-01': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_MajorShareholders-01', '経理の状況': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_FinancialInformation', '貸借対照表関係': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_NotesBalanceSheet', '損益計算書関係': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_NotesStatementOfIncome', '重要な会計方針、財務諸表': 'http://disclosure.edinet-fsa.go.jp/role/jpcrp/rol_NotesSignificantAccountingPoliciesFinancialStatements', '貸借対照表': 'http://disclosure.edinet-fsa.go.jp/role/jppfs/rol_BalanceSheet', '損益計算書': 'http://disclosure.edinet-fsa.go.jp/role/jppfs/rol_StatementOfIncome', '株主資本等変動計算書': 'http://disclosure.edinet-fsa.go.jp/role/jppfs/rol_StatementOfChangesInEquity'}

# %% [markdown]
# Read Structure of "企業内容等の開示に関する内閣府令 第三号様式 有価証券報告書"

# %%
document = presentation.find(
                "link:presentationLink",
                {"xlink:role": roles["企業内容等の開示に関する内閣府令 第三号様式 有価証券報告書"]})


class Node():

    def __init__(self, key, order=0):
        self.key = key
        self.parent = None
        self.order = order

    def add_parent(self, parent):
        self.parent = parent
    
    @property
    def path(self):
        path = self.key
        p = self.parent
        while p is not None:
            path = p.key + "/" + path
            p = p.parent
        return path + " " + str(self.order)

nodes = {}
for i, arc in enumerate(document.find_all("link:presentationArc")):
    if not arc["xlink:arcrole"].endswith("parent-child"):
        print("Unexpected arctype.")
        continue
    
    parent = arc["xlink:from"]
    child = arc["xlink:to"]
    order = arc["order"]

    if child in nodes:
        nodes[child].order = order
    else:
        nodes[child] = Node(child, order)

    if parent not in nodes:
        nodes[parent] = Node(parent, i)
    
    nodes[child].add_parent(nodes[parent])

keys = {}
for name in nodes:
    n = nodes[name]
    path = n.path
    keys[path] = n


for key in sorted(keys.keys()):
    indent = "_" * len(key.split("/"))
    print(indent + keys[key].key)
# Out:
# _AcquisitionsByResolutionOfBoardOfDirectorsMeetingHeading
# __AcquisitionsByResolutionOfBoardOfDirectorsMeetingNATextBlock
# _AcquisitionsByResolutionOfShareholdersMeetingHeading
# __AcquisitionsByResolutionOfShareholdersMeetingNATextBlock
# _AcquisitionsEtcOfTreasurySharesHeading
# __AcquisitionsByResolutionOfBoardOfDirectorsMeetingHeading_2
# __AcquisitionsByResolutionOfShareholdersMeetingHeading_2
# __AcquisitionsNotBasedOnResolutionOfShareholdersMeetingOrBoardOfDirectorsMeetingHeading_2
# __ClassesOfSharesEtcHeading_2
# __DisposalsOrHoldingOfAcquiredTreasurySharesHeading_2
# _AcquisitionsNotBasedOnResolutionOfShareholdersMeetingOrBoardOfDirectorsMeetingHeading
# __AcquisitionsNotBasedOnResolutionOfShareholdersMeetingOrBoardOfDirectorsMeetingNATextBlock
# _AnnexedDetailedScheduleOfPropertyPlantAndEquipmentEtcHeading
# __AnnexedDetailedScheduleOfPropertyPlantAndEquipmentEtcTextBlock
# _AnnexedDetailedScheduleOfProvisionsHeading
# __AnnexedDetailedScheduleOfProvisionsTextBlock
# _AnnexedDetailedScheduleOfSecuritiesHeading
# __AnnexedDetailedScheduleOfSecuritiesTextBlock
# _AnnexedDetailedSchedulesHeading
# __AnnexedDetailedScheduleOfPropertyPlantAndEquipmentEtcHeading_2
# __AnnexedDetailedScheduleOfProvisionsHeading_2
# __AnnexedDetailedScheduleOfSecuritiesHeading_2
# _BalanceSheetHeading
# __BalanceSheetTextBlock
# _BusinessPolicyBusinessEnvironmentIssuesToAddressEtcHeading
# __BusinessPolicyBusinessEnvironmentIssuesToAddressEtcTextBlock
# _BusinessResultsOfGroupHeading
# __BusinessResultsOfGroupTextBlock
# _BusinessResultsOfReportingCompanyHeading
# __BusinessResultsOfReportingCompanyTextBlock
# _BusinessRisksHeading
# __BusinessRisksTextBlock_2
# _CabinetOfficeOrdinanceOnDisclosureOfCorporateInformationEtcFormNo3AnnualSecuritiesReportHeading
# __CompanyInformationHeading_2
# __CoverPageHeading
# __InformationAboutCompanyWhichProvidesGuaranteeToReportingCompanyHeading_2
# _ChangesInNumberOfIssuedSharesStatedCapitalEtcHeading
# __ChangesInNumberOfIssuedSharesStatedCapitalEtcTextBlock
# _ClassesOfSharesEtcHeading
# __ClassesOfSharesEtcTextBlock
# _CompanyHistoryHeading
# __CompanyHistoryTextBlock
# _CompanyInformationHeading
# __FinancialInformationHeading_2
# __InformationAboutFacilitiesHeading_2
# __InformationAboutReportingCompanyHeading_2
# __OverviewOfBusinessHeading_2
# __OverviewOfCompanyHeading_2
# __OverviewOfOperationalProceduresForSharesHeading_2
# __ReferenceInformationOfReportingCompanyHeading_2
# _ComponentsOfMajorAssetsAndLiabilitiesHeading
# __DescriptionOfFactAndReasonWhyComponentsOfMajorAssetsAndLiabilitiesAreNotPresented
# _ConsolidatedBalanceSheetHeading
# __ConsolidatedStatementOfFinancialPositionIFRSTextBlock
# _ConsolidatedFinancialStatementsEtcHeading
# __ConsolidatedFinancialStatementsHeading_2
# __OtherInformationConsolidatedFinancialStatementsEtcHeading_2
# _ConsolidatedFinancialStatementsHeading
# __ConsolidatedBalanceSheetHeading_2
# __ConsolidatedStatementOfCashFlowsHeading_2
# __ConsolidatedStatementOfChangesInEquityHeading_2
# __ConsolidatedStatementOfComprehensiveIncomeHeading_2
# __ConsolidatedStatementOfIncomeHeading_2
# __NotesToConsolidatedFinancialStatementsIFRSHeading_2
# _ConsolidatedStatementOfCashFlowsHeading
# __ConsolidatedStatementOfCashFlowsIFRSTextBlock
# _ConsolidatedStatementOfChangesInEquityHeading
# __ConsolidatedStatementOfChangesInEquityIFRSTextBlock
# _ConsolidatedStatementOfComprehensiveIncomeHeading
# __ConsolidatedStatementOfComprehensiveIncomeIFRSTextBlock
# _ConsolidatedStatementOfIncomeHeading
# __ConsolidatedStatementOfIncomeIFRSTextBlock
# _CriticalContractsForOperationHeading
# __CriticalContractsForOperationTextBlock
# _DescriptionOfBusinessHeading
# __DescriptionOfBusinessTextBlock
# _DescriptionOfRightsPlanHeading
# __DescriptionOfRightsPlanNATextBlock
# _DetailsOfAuditFeeEtcHeading
# __DetailsOfNonAuditServicesRenderedByIndependentAuditorsHeading_2
# __DetailsOfRemunerationToIndependentAuditorsHeading_2
# __OtherMaterialRemunerationToIndependentAuditorsHeading_2
# __PolicyOnDeterminingAuditFeeHeading_2
# _DetailsOfEmployeeShareOptionProgramHeading
# __DetailsOfEmployeeShareOptionProgramNATextBlock
# _DetailsOfNonAuditServicesRenderedByIndependentAuditorsHeading
# __DetailsOfNonAuditServicesRenderedByIndependentAuditorsTextBlock
# _DetailsOfRemunerationToIndependentAuditorsHeading
# __DetailsOfRemunerationToIndependentAuditorsTextBlock
# _DisposalsOrHoldingOfAcquiredTreasurySharesHeading
# __DisposalsOrHoldingOfAcquiredTreasurySharesTextBlock
# _DividendPolicyHeading
# __DividendPolicyTextBlock
# _ExercisesEtcOfMovingStrikeConvertibleBondsEtcHeading
# __ExercisesEtcOfMovingStrikeConvertibleBondsEtcNATextBlock
# _ExplanationAboutCorporateGovernanceEtcHeading
# __DetailsOfAuditFeeEtcHeading_2
# __ExplanationAboutCorporateGovernanceHeading_2
# _ExplanationAboutCorporateGovernanceHeading
# __ExplanationAboutCorporateGovernanceTextBlock
# _FinancialInformationHeading
# __ConsolidatedFinancialStatementsEtcHeading_2
# __FinancialStatementsEtcHeading_2
# _FinancialStatementsEtcHeading
# __ComponentsOfMajorAssetsAndLiabilitiesHeading_2
# __FinancialStatementsHeading_2
# __OtherInformationFinancialStatementsEtcHeading_2
# _FinancialStatementsHeading
# __AnnexedDetailedSchedulesHeading_2
# __BalanceSheetHeading_2
# __NotesFinancialStatementsHeading_2
# __StatementOfChangesInEquityHeading_2
# __StatementOfIncomeHeading_2
# _HistoricalRecordsOfSharePriceHeading
# __HistoricalRecordsOfSharePriceNATextBlock
# _InformationAboutCompanyWhichProvidesGuaranteeToReportingCompanyHeading
# __InformationAboutCompanyWhichProvidesGuaranteeToReportingCompanyNATextBlock
# _InformationAboutEmployeesHeading
# __InformationAboutEmployeesTextBlock
# _InformationAboutFacilitiesHeading
# __MajorFacilitiesHeading_2
# __OverviewOfCapitalExpendituresEtcHeading_2
# __PlannedAdditionsRetirementsEtcOfFacilitiesHeading_2
# _InformationAboutOfficersHeading
# __InformationAboutOfficersTextBlock
# _InformationAboutParentCompanyEtcOfReportingCompanyHeading
# __InformationAboutParentCompanyEtcOfReportingCompanyNATextBlock
# _InformationAboutReportingCompanyHeading
# __AcquisitionsEtcOfTreasurySharesHeading_2
# __DividendPolicyHeading_2
# __ExplanationAboutCorporateGovernanceEtcHeading_2
# __HistoricalRecordsOfSharePriceHeading_2
# __InformationAboutOfficersHeading_2
# __InformationAboutSharesEtcHeading_2
# _InformationAboutSharesEtcHeading
# __ChangesInNumberOfIssuedSharesStatedCapitalEtcHeading_2
# __ExercisesEtcOfMovingStrikeConvertibleBondsEtcHeading_2
# __MajorShareholdersHeading_2
# __ShareholdingByShareholderCategoryHeading_2
# __SubscriptionRightsToSharesEtcHeading_2
# __TotalNumberOfSharesEtcHeading_2
# __VotingRightsHeading_2
# _IssuedSharesTotalNumberOfSharesEtcHeading
# __IssuedSharesTotalNumberOfSharesEtcTextBlock
# _IssuedSharesVotingRightsHeading
# __IssuedSharesVotingRightsTextBlock
# _MajorFacilitiesHeading
# __MajorFacilitiesTextBlock
# _MajorShareholdersHeading
# __MajorShareholdersTextBlock
# _ManagementAnalysisOfFinancialPositionOperatingResultsAndCashFlowsHeading
# __ManagementAnalysisOfFinancialPositionOperatingResultsAndCashFlowsTextBlock_2
# _NotesFinancialStatementsHeading
# __NotesBalanceSheetHeading
# __NotesSecuritiesFinancialStatementsHeading_2
# __NotesSignificantAccountingPoliciesFinancialStatementsHeading_2
# __NotesSignificantEventsAfterReportingPeriodFinancialStatementsHeading_2
# __NotesStatementOfIncomeHeading
# __NotesTaxEffectAccountingFinancialStatementsHeading_2
# _NotesSecuritiesFinancialStatementsHeading
# __NotesSecuritiesFinancialStatementsTextBlock
# _NotesSignificantAccountingPoliciesFinancialStatementsHeading
# __NotesSignificantAccountingPoliciesFinancialStatementsTextBlock
# _NotesSignificantEventsAfterReportingPeriodFinancialStatementsHeading
# __NotesSignificantEventsAfterReportingPeriodFinancialStatementsNATextBlock
# _NotesTaxEffectAccountingFinancialStatementsHeading
# __NotesTaxEffectAccountingFinancialStatementsTextBlock
# _NotesToConsolidatedFinancialStatementsIFRSHeading
# __NotesToConsolidatedFinancialStatementsIFRSTextBlock
# _OtherInformationAboutShareAcquisitionRightsHeading
# __OtherInformationAboutShareAcquisitionRightsNATextBlock
# _OtherInformationConsolidatedFinancialStatementsEtcHeading
# __OtherInformationConsolidatedFinancialStatementsEtcNATextBlock
# _OtherInformationFinancialStatementsEtcHeading
# __OtherInformationFinancialStatementsEtcNATextBlock
# _OtherMaterialRemunerationToIndependentAuditorsHeading
# __OtherMaterialRemunerationToIndependentAuditorsTextBlock
# _OtherReferenceInformationHeading
# __OtherReferenceInformationTextBlock
# _OverviewOfAffiliatedEntitiesHeading
# __OverviewOfAffiliatedEntitiesTextBlock
# _OverviewOfBusinessHeading
# __BusinessPolicyBusinessEnvironmentIssuesToAddressEtcHeading_2
# __BusinessRisksHeading_2
# __CriticalContractsForOperationHeading_2
# __ManagementAnalysisOfFinancialPositionOperatingResultsAndCashFlowsHeading_2
# __ResearchAndDevelopmentActivitiesHeading_2
# _OverviewOfCapitalExpendituresEtcHeading
# __OverviewOfCapitalExpendituresEtcTextBlock
# _OverviewOfCompanyHeading
# __CompanyHistoryHeading_2
# __DescriptionOfBusinessHeading_2
# __InformationAboutEmployeesHeading_2
# __OverviewOfAffiliatedEntitiesHeading_2
# __SummaryOfBusinessResultsHeading_2
# _OverviewOfOperationalProceduresForSharesHeading
# __OverviewOfOperationalProceduresForSharesTextBlock
# _PlannedAdditionsRetirementsEtcOfFacilitiesHeading
# __PlannedAdditionsRetirementsEtcOfFacilitiesTextBlock
# _PolicyOnDeterminingAuditFeeHeading
# __PolicyOnDeterminingAuditFeeTextBlock
# _ReferenceInformationOfReportingCompanyHeading
# __InformationAboutParentCompanyEtcOfReportingCompanyHeading_2
# __OtherReferenceInformationHeading_2
# _ResearchAndDevelopmentActivitiesHeading
# __ResearchAndDevelopmentActivitiesTextBlock
# _ShareholdingByShareholderCategoryHeading
# __ShareholdingByShareholderCategoryTextBlock
# _StatementOfChangesInEquityHeading
# __StatementOfChangesInEquityTextBlock
# _StatementOfIncomeHeading
# __StatementOfIncomeTextBlock
# _SubscriptionRightsToSharesEtcHeading
# __DescriptionOfRightsPlanHeading_2
# __DetailsOfEmployeeShareOptionProgramHeading_2
# __OtherInformationAboutShareAcquisitionRightsHeading_2
# _SummaryOfBusinessResultsHeading
# __BusinessResultsOfGroupHeading_2
# __BusinessResultsOfReportingCompanyHeading_2
# _TotalNumberOfSharesEtcHeading
# __IssuedSharesTotalNumberOfSharesEtcHeading_2
# __TotalNumberOfSharesHeading_2
# _TotalNumberOfSharesHeading
# __TotalNumberOfSharesTextBlock
# _TreasurySharesEtcHeading
# __TreasurySharesEtcTextBlock
# _VotingRightsHeading
# __IssuedSharesVotingRightsHeading_2
# __TreasurySharesEtcHeading_2

# %% [markdown]
# ## Read Document Schema
#
# Get namespaces

# %%
import dataclasses


@dataclasses.dataclass
class Namespace:
    name: str
    namespace: str
    location: str

# %% [markdown]
# Read from taxonomy
